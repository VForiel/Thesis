# %% [markdown]
# # Analyse : distribution_model
#
# Notebook de démonstration pour module d'analyse.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd() / 'src'))
print(' distribution_model')
